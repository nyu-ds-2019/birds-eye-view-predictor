# %%
# Import some libraries

import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.datasets as datasets

import os
import pickle
import numpy as np

from skimage import io

from matplotlib import pyplot as plt
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['image.interpolation'] = 'nearest'
mpl.rcParams['figure.figsize'] = 15, 25

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
np.random.seed(0)
torch.manual_seed(0)

data = "parts_data"
batch_size = 256
workers = 4
distributed = False

# Data loading code
train_dir = os.path.join(data, 'train')
val_dir = os.path.join(data, 'val')
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
class NormalizeInverse(torchvision.transforms.Normalize):
    """
    Ref: https://discuss.pytorch.org/t/simple-way-to-inverse-transform-normalization/4821
    Undoes the normalization and returns the reconstructed images in the input domain.
    """

    def __init__(self, mean, std):
        mean = torch.as_tensor(mean)
        std = torch.as_tensor(std)
        std_inv = 1 / (std + 1e-7)
        mean_inv = -mean * std_inv
        super().__init__(mean=mean_inv, std=std_inv)

    def __call__(self, tensor):
        return super().__call__(tensor.clone())
inv_normalize = NormalizeInverse(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

# Ref: https://pytorch.org/docs/stable/torchvision/transforms.html

train_dataset = datasets.ImageFolder(
    train_dir,
    transforms.Compose([
#         transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))

if distributed:
    train_sampler = torch.utils.data.distributed.DistributedSampler(train_dataset)
else:
    train_sampler = None

train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=(train_sampler is None),
        num_workers=workers, pin_memory=True, sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(val_dir, transforms.Compose([
#         transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        normalize,
    ])),
    batch_size=batch_size, shuffle=False,
    num_workers=workers, pin_memory=True)

# input_dim = io.imread(train_dataset.imgs[0][0]).transpose(2,0,1).shape
# nw_input_dim = (batch_size,) + input_dim

input_dim = (3, ) + io.imread(train_dataset.imgs[0][0]).shape
input_dim = (3, 256, 306)

# %%
train_dataset.classes[y[i].item()]
# Out:
# '114_39'

# %%
X, y = iter(train_loader).next()
print(X.shape)
plt.figure(figsize=(18,18))
for i in range(len(X)):
    plt.subplot(6,6,i+1)
    plt.imshow(torch.clamp(inv_normalize(X[i]), 0, 1).permute(1,2,0))
    plt.xticks([]), plt.yticks([])
plt.tight_layout()
# Out:
# torch.Size([256, 3, 128, 128])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-68b639549b84> in <module>
#       3 plt.figure(figsize=(18,18))
#       4 for i in range(len(X)):
# ----> 5     plt.subplot(6,6,i+1)
#       6     plt.imshow(torch.clamp(inv_normalize(X[i]), 0, 1).permute(1,2,0))
#       7     plt.xticks([]), plt.yticks([])
#
# /usr/local/anaconda3/envs/dl-minicourse/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# /usr/local/anaconda3/envs/dl-minicourse/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /usr/local/anaconda3/envs/dl-minicourse/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 36, not 37

# %%
y

# %%
import ConvAE_AutoConf as ConvAE

input_dim = (3, 800, 800)
feature_maps = 96
depth = 8
pooling_freq = 1e100 # large number to disable pooling layers
batch_norm_freq = 2
strided_conv_freq = 2
strided_conv_feature_maps = 8
code_size = 8

CONV_ENC_BLOCK = [("conv1", feature_maps), ("relu1", None)]
CONV_ENC_LAYERS = ConvAE.create_network(
    CONV_ENC_BLOCK, depth, 
    pooling_freq=pooling_freq,
    strided_conv_freq=strided_conv_freq, 
    strided_conv_channels=strided_conv_feature_maps,
    batch_norm_freq=batch_norm_freq)

CONV_ENC_NW = CONV_ENC_LAYERS + [("flatten1", None), ("linear1", 1024), ("relu1", None), ("linear1", 64)]
model = ConvAE.ConvAE(input_dim, enc_config=CONV_ENC_NW, store_activations=False)
# print("Encoder Nw Spec:")
# CONV_ENC_NW
print(model)
# Out:
# ConvAE(
#   (encoder): ModuleList(
#     (0): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU()
#     (2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (3): ReLU()
#     (4): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): ReLU()
#     (8): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (9): ReLU()
#     (10): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (13): ReLU()
#     (14): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): ReLU()
#     (16): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (17): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (19): ReLU()
#     (20): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (21): ReLU()
#     (22): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (23): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): Reshape()
#     (25): Linear(in_features=20000, out_features=1024, bias=True)
#     (26): ReLU()
#     (27): Linear(in_features=1024, out_features=64, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): Linear(in_features=64, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=20000, bias=True)
#     (3): Reshape()
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): ReLU()
#     (7): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (8): ReLU()
#     (9): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (12): ReLU()
#     (13): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (14): ReLU()
#     (15): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (18): ReLU()
#     (19): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (20): ReLU()
#     (21): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (22): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (24): ReLU()
#     (25): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (26): ReLU()
#     (27): ConvTranspose2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (tanh): Tanh()
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class DeFlatten(nn.Module):
    def __init__(self, *args):
        super(DeFlatten, self).__init__()
        self.shape = args

    def forward(self, x):
        return x.view(self.shape)

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            Flatten(),
            nn.Linear(in_features=8192, out_features=1024, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=1024, out_features=64, bias=True)
        )
        self.decoder = nn.Sequential(
            nn.Linear(in_features=64, out_features=1024, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=1024, out_features=8192, bias=True),
            DeFlatten(-1, 8, 32, 32),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.ReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.ReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.ConvTranspose2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
        )

    def forward(self, x):
        x = self.encoder(x)
        noise = Variable(torch.randn(x.size()) * 0.3)
        x = self.decoder(x + noise)
        return x
    
model = Autoencoder().to(device)
criterion = nn.MSELoss()

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Conv2d(96, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            Flatten(),
            nn.Linear(in_features=1536, out_features=1024, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=1024, out_features=256, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=256, out_features=64, bias=True),
        )
    def forward(self, x):
        x = self.encoder(x)
        return x

# %%
# model = CNN()
from torchsummary import summary
from torchvision import models

summary(model, (3, 800, 800))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 96, 800, 800]           2,592
#               ReLU-2         [-1, 96, 800, 800]               0
#             Conv2d-3         [-1, 96, 800, 800]          82,944
#               ReLU-4         [-1, 96, 800, 800]               0
#             Conv2d-5          [-1, 8, 400, 400]           6,912
#        BatchNorm2d-6          [-1, 8, 400, 400]              16
#             Conv2d-7         [-1, 96, 400, 400]           6,912
#               ReLU-8         [-1, 96, 400, 400]               0
#             Conv2d-9         [-1, 96, 400, 400]          82,944
#              ReLU-10         [-1, 96, 400, 400]               0
#            Conv2d-11          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-12          [-1, 8, 200, 200]              16
#            Conv2d-13         [-1, 96, 200, 200]           6,912
#              ReLU-14         [-1, 96, 200, 200]               0
#            Conv2d-15         [-1, 96, 200, 200]          82,944
#              ReLU-16         [-1, 96, 200, 200]               0
#            Conv2d-17          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-18          [-1, 8, 100, 100]              16
#            Conv2d-19         [-1, 96, 100, 100]           6,912
#              ReLU-20         [-1, 96, 100, 100]               0
#            Conv2d-21         [-1, 96, 100, 100]          82,944
#              ReLU-22         [-1, 96, 100, 100]               0
#            Conv2d-23            [-1, 8, 50, 50]           6,912
#       BatchNorm2d-24            [-1, 8, 50, 50]              16
#           Reshape-25                [-1, 20000]               0
#            Linear-26                 [-1, 1024]      20,481,024
#              ReLU-27                 [-1, 1024]               0
#            Linear-28                   [-1, 64]          65,600
#            Linear-29                 [-1, 1024]          66,560
#              ReLU-30                 [-1, 1024]               0
#            Linear-31                [-1, 20000]      20,500,000
#           Reshape-32            [-1, 8, 50, 50]               0
#       BatchNorm2d-33            [-1, 8, 50, 50]              16
#   ConvTranspose2d-34         [-1, 96, 100, 100]           6,912
#              ReLU-35         [-1, 96, 100, 100]               0
#   ConvTranspose2d-36         [-1, 96, 100, 100]          82,944
#              ReLU-37         [-1, 96, 100, 100]               0
#   ConvTranspose2d-38          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-39          [-1, 8, 100, 100]              16
#   ConvTranspose2d-40         [-1, 96, 200, 200]           6,912
#              ReLU-41         [-1, 96, 200, 200]               0
#   ConvTranspose2d-42         [-1, 96, 200, 200]          82,944
#              ReLU-43         [-1, 96, 200, 200]               0
#   ConvTranspose2d-44          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-45          [-1, 8, 200, 200]              16
#   ConvTranspose2d-46         [-1, 96, 400, 400]           6,912
#              ReLU-47         [-1, 96, 400, 400]               0
#   ConvTranspose2d-48         [-1, 96, 400, 400]          82,944
#              ReLU-49         [-1, 96, 400, 400]               0
#   ConvTranspose2d-50          [-1, 8, 400, 400]           6,912
#       BatchNorm2d-51          [-1, 8, 400, 400]              16
#   ConvTranspose2d-52         [-1, 96, 800, 800]           6,912
#              ReLU-53         [-1, 96, 800, 800]               0
#   ConvTranspose2d-54         [-1, 96, 800, 800]          82,944
#              ReLU-55         [-1, 96, 800, 800]               0
#   ConvTranspose2d-56          [-1, 3, 800, 800]           2,592
#              Tanh-57          [-1, 3, 800, 800]               0
# ================================================================
# Total params: 41,878,816
# Trainable params: 41,878,816
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 7.32
# Forward/backward pass size (MB): 5061.98
# Params size (MB): 159.76
# Estimated Total Size (MB): 5229.06
# ----------------------------------------------------------------

# %%
from torchsummary import summary
from torchvision import models

model = models.resnet18()

model.fc = nn.Linear(512, 64)

summary(model, (3, 256, 306))
# print(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 153]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 153]             128
#               ReLU-3         [-1, 64, 128, 153]               0
#          MaxPool2d-4           [-1, 64, 64, 77]               0
#             Conv2d-5           [-1, 64, 64, 77]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 77]             128
#               ReLU-7           [-1, 64, 64, 77]               0
#             Conv2d-8           [-1, 64, 64, 77]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 77]             128
#              ReLU-10           [-1, 64, 64, 77]               0
#        BasicBlock-11           [-1, 64, 64, 77]               0
#            Conv2d-12           [-1, 64, 64, 77]          36,864
#       BatchNorm2d-13           [-1, 64, 64, 77]             128
#              ReLU-14           [-1, 64, 64, 77]               0
#            Conv2d-15           [-1, 64, 64, 77]          36,864
#       BatchNorm2d-16           [-1, 64, 64, 77]             128
#              ReLU-17           [-1, 64, 64, 77]               0
#        BasicBlock-18           [-1, 64, 64, 77]               0
#            Conv2d-19          [-1, 128, 32, 39]          73,728
#       BatchNorm2d-20          [-1, 128, 32, 39]             256
#              ReLU-21          [-1, 128, 32, 39]               0
#            Conv2d-22          [-1, 128, 32, 39]         147,456
#       BatchNorm2d-23          [-1, 128, 32, 39]             256
#            Conv2d-24          [-1, 128, 32, 39]           8,192
#       BatchNorm2d-25          [-1, 128, 32, 39]             256
#              ReLU-26          [-1, 128, 32, 39]               0
#        BasicBlock-27          [-1, 128, 32, 39]               0
#            Conv2d-28          [-1, 128, 32, 39]         147,456
#       BatchNorm2d-29          [-1, 128, 32, 39]             256
#              ReLU-30          [-1, 128, 32, 39]               0
#            Conv2d-31          [-1, 128, 32, 39]         147,456
#       BatchNorm2d-32          [-1, 128, 32, 39]             256
#              ReLU-33          [-1, 128, 32, 39]               0
#        BasicBlock-34          [-1, 128, 32, 39]               0
#            Conv2d-35          [-1, 256, 16, 20]         294,912
#       BatchNorm2d-36          [-1, 256, 16, 20]             512
#              ReLU-37          [-1, 256, 16, 20]               0
#            Conv2d-38          [-1, 256, 16, 20]         589,824
#       BatchNorm2d-39          [-1, 256, 16, 20]             512
#            Conv2d-40          [-1, 256, 16, 20]          32,768
#       BatchNorm2d-41          [-1, 256, 16, 20]             512
#              ReLU-42          [-1, 256, 16, 20]               0
#        BasicBlock-43          [-1, 256, 16, 20]               0
#            Conv2d-44          [-1, 256, 16, 20]         589,824
#       BatchNorm2d-45          [-1, 256, 16, 20]             512
#              ReLU-46          [-1, 256, 16, 20]               0
#            Conv2d-47          [-1, 256, 16, 20]         589,824
#       BatchNorm2d-48          [-1, 256, 16, 20]             512
#              ReLU-49          [-1, 256, 16, 20]               0
#        BasicBlock-50          [-1, 256, 16, 20]               0
#            Conv2d-51           [-1, 512, 8, 10]       1,179,648
#       BatchNorm2d-52           [-1, 512, 8, 10]           1,024
#              ReLU-53           [-1, 512, 8, 10]               0
#            Conv2d-54           [-1, 512, 8, 10]       2,359,296
#       BatchNorm2d-55           [-1, 512, 8, 10]           1,024
#            Conv2d-56           [-1, 512, 8, 10]         131,072
#       BatchNorm2d-57           [-1, 512, 8, 10]           1,024
#              ReLU-58           [-1, 512, 8, 10]               0
#        BasicBlock-59           [-1, 512, 8, 10]               0
#            Conv2d-60           [-1, 512, 8, 10]       2,359,296
#       BatchNorm2d-61           [-1, 512, 8, 10]           1,024
#              ReLU-62           [-1, 512, 8, 10]               0
#            Conv2d-63           [-1, 512, 8, 10]       2,359,296
#       BatchNorm2d-64           [-1, 512, 8, 10]           1,024
#              ReLU-65           [-1, 512, 8, 10]               0
#        BasicBlock-66           [-1, 512, 8, 10]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 64]          32,832
# ================================================================
# Total params: 11,209,344
# Trainable params: 11,209,344
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.90
# Forward/backward pass size (MB): 99.29
# Params size (MB): 42.76
# Estimated Total Size (MB): 142.94
# ----------------------------------------------------------------

# %%
# Configure the optimiser

learning_rate = 1e-3

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=learning_rate,
)

# %%
# Displaying routine

def display_images(in_, out, n=1):
    for N in range(n):
        if in_ is not None:
            in_pic = to_img(in_.cpu().data)
            plt.figure(figsize=(18, 6))
            for i in range(4):
                plt.subplot(1,4,i+1)
                plt.imshow(in_pic[i+4*N])
                plt.axis('off')
        out_pic = to_img(out.cpu().data)
        plt.figure(figsize=(18, 6))
        for i in range(4):
            plt.subplot(1,4,i+1)
            plt.imshow(out_pic[i+4*N])
            plt.axis('off')

# %%
# Convert vector to image

def to_img(x):
    x = 0.5 * (x + 1)
    x = x.view(x.size(0), 28, 28)
    return x

# %%
# Train standard or denoising autoencoder (AE)

num_epochs = 1
for epoch in range(num_epochs):
    for data in train_loader:
        img, _ = data
        img = img.to(device)
        # ===================forward=====================
        output = model(img)  # feed <img> (for std AE) or <img_bad> (for denoising AE)
        loss = criterion(output, img.data)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # ===================log========================
        print(f'epoch [{epoch + 1}/{num_epochs}], loss:{loss.item():.4f}')
    display_images(None, output)  # pass (None, output) for std AE, (img_bad, output) for denoising AE

# %%
out, code = model(X)
code
# Out:
# tensor([[-0.0349, -0.3413, -0.0890,  ..., -0.0262,  0.0744,  0.0523],
#         [-0.0126, -0.2566, -0.0910,  ..., -0.0681,  0.0760,  0.1393],
#         [-0.0027, -0.2601, -0.1302,  ..., -0.0485,  0.0139,  0.0435],
#         ...,
#         [-0.1074,  0.0227,  0.1682,  ..., -0.1505,  0.0291, -0.0524],
#         [ 0.0267, -0.2297, -0.1341,  ..., -0.0623,  0.1036,  0.1470],
#         [ 0.0034, -0.1981,  0.1188,  ..., -0.0243, -0.2028, -0.1521]],
#        grad_fn=<AddmmBackward>)

# %%
X.shape
# Out:
# torch.Size([32, 3, 128, 128])

# %%
code.shape
# Out:
# torch.Size([32, 256])

# %%
plt.figure(figsize=(20,20))
plt.imshow(code.detach().numpy(), cmap="gray")

# %%
out_normalized = torch.clamp(
    model.get_results_img(torch.stack([inv_normalize(img.detach()) for img in X]), 
                                       torch.stack([inv_normalize(img.detach()) for img in out])), 0, 1)

# %%
plt.figure(figsize=(18,18))
plt.imshow(out_normalized.detach())

# %%
import ConvAE_AutoConf as ConvAE

input_dim = (3, 800, 800)
feature_maps = 96
depth = 15
pooling_freq = 1e100 # large number to disable pooling layers
batch_norm_freq = 2
strided_conv_freq = 2
strided_conv_feature_maps = 8
code_size = 8

CONV_ENC_BLOCK = [("conv1", feature_maps), ("relu1", None)]
CONV_ENC_LAYERS = ConvAE.create_network(
    CONV_ENC_BLOCK, depth, 
    pooling_freq=pooling_freq,
    strided_conv_freq=strided_conv_freq, 
    strided_conv_channels=strided_conv_feature_maps,
    batch_norm_freq=batch_norm_freq)

CONV_ENC_NW = CONV_ENC_LAYERS + [("flatten1", None), ("linear1", 1024), ("relu1", None), ("linear1", 64)]
model = ConvAE.ConvAE(input_dim, enc_config=CONV_ENC_NW, store_activations=False)
# print("Encoder Nw Spec:")
# CONV_ENC_NW
print(model)
# Out:
# ConvAE(
#   (encoder): ModuleList(
#     (0): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU()
#     (2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (3): ReLU()
#     (4): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): ReLU()
#     (8): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (9): ReLU()
#     (10): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (13): ReLU()
#     (14): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): ReLU()
#     (16): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (17): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (19): ReLU()
#     (20): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (21): ReLU()
#     (22): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (23): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (25): ReLU()
#     (26): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (27): ReLU()
#     (28): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (29): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (31): ReLU()
#     (32): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (33): ReLU()
#     (34): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (35): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (37): ReLU()
#     (38): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (39): ReLU()
#     (40): Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (41): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (43): ReLU()
#     (44): Reshape()
#     (45): Linear(in_features=4704, out_features=1024, bias=True)
#     (46): ReLU()
#     (47): Linear(in_features=1024, out_features=64, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): Linear(in_features=64, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=4704, bias=True)
#     (3): Reshape()
#     (4): ReLU()
#     (5): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (8): ReLU()
#     (9): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): ReLU()
#     (11): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (12): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (14): ReLU()
#     (15): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): ReLU()
#     (17): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (18): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (20): ReLU()
#     (21): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (22): ReLU()
#     (23): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (24): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (26): ReLU()
#     (27): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (28): ReLU()
#     (29): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (30): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (31): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (32): ReLU()
#     (33): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (34): ReLU()
#     (35): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (36): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (37): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (38): ReLU()
#     (39): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (40): ReLU()
#     (41): ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (42): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (43): ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (44): ReLU()
#     (45): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (46): ReLU()
#     (47): ConvTranspose2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (tanh): Tanh()
# )

# %%
summary(model, (3, 800, 800))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 96, 800, 800]           2,592
#               ReLU-2         [-1, 96, 800, 800]               0
#             Conv2d-3         [-1, 96, 800, 800]          82,944
#               ReLU-4         [-1, 96, 800, 800]               0
#             Conv2d-5          [-1, 8, 400, 400]           6,912
#        BatchNorm2d-6          [-1, 8, 400, 400]              16
#             Conv2d-7         [-1, 96, 400, 400]           6,912
#               ReLU-8         [-1, 96, 400, 400]               0
#             Conv2d-9         [-1, 96, 400, 400]          82,944
#              ReLU-10         [-1, 96, 400, 400]               0
#            Conv2d-11          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-12          [-1, 8, 200, 200]              16
#            Conv2d-13         [-1, 96, 200, 200]           6,912
#              ReLU-14         [-1, 96, 200, 200]               0
#            Conv2d-15         [-1, 96, 200, 200]          82,944
#              ReLU-16         [-1, 96, 200, 200]               0
#            Conv2d-17          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-18          [-1, 8, 100, 100]              16
#            Conv2d-19         [-1, 96, 100, 100]           6,912
#              ReLU-20         [-1, 96, 100, 100]               0
#            Conv2d-21         [-1, 96, 100, 100]          82,944
#              ReLU-22         [-1, 96, 100, 100]               0
#            Conv2d-23            [-1, 8, 50, 50]           6,912
#       BatchNorm2d-24            [-1, 8, 50, 50]              16
#            Conv2d-25           [-1, 96, 50, 50]           6,912
#              ReLU-26           [-1, 96, 50, 50]               0
#            Conv2d-27           [-1, 96, 50, 50]          82,944
#              ReLU-28           [-1, 96, 50, 50]               0
#            Conv2d-29            [-1, 8, 25, 25]           6,912
#       BatchNorm2d-30            [-1, 8, 25, 25]              16
#            Conv2d-31           [-1, 96, 25, 25]           6,912
#              ReLU-32           [-1, 96, 25, 25]               0
#            Conv2d-33           [-1, 96, 25, 25]          82,944
#              ReLU-34           [-1, 96, 25, 25]               0
#            Conv2d-35            [-1, 8, 13, 13]           6,912
#       BatchNorm2d-36            [-1, 8, 13, 13]              16
#            Conv2d-37           [-1, 96, 13, 13]           6,912
#              ReLU-38           [-1, 96, 13, 13]               0
#            Conv2d-39           [-1, 96, 13, 13]          82,944
#              ReLU-40           [-1, 96, 13, 13]               0
#            Conv2d-41              [-1, 8, 7, 7]           6,912
#       BatchNorm2d-42              [-1, 8, 7, 7]              16
#            Conv2d-43             [-1, 96, 7, 7]           6,912
#              ReLU-44             [-1, 96, 7, 7]               0
#           Reshape-45                 [-1, 4704]               0
#            Linear-46                 [-1, 1024]       4,817,920
#              ReLU-47                 [-1, 1024]               0
#            Linear-48                   [-1, 64]          65,600
#            Linear-49                 [-1, 1024]          66,560
#              ReLU-50                 [-1, 1024]               0
#            Linear-51                 [-1, 4704]       4,821,600
#           Reshape-52             [-1, 96, 7, 7]               0
#              ReLU-53             [-1, 96, 7, 7]               0
#   ConvTranspose2d-54              [-1, 8, 7, 7]           6,912
#       BatchNorm2d-55              [-1, 8, 7, 7]              16
#   ConvTranspose2d-56           [-1, 96, 13, 13]           6,912
#              ReLU-57           [-1, 96, 13, 13]               0
#   ConvTranspose2d-58           [-1, 96, 13, 13]          82,944
#              ReLU-59           [-1, 96, 13, 13]               0
#   ConvTranspose2d-60            [-1, 8, 13, 13]           6,912
#       BatchNorm2d-61            [-1, 8, 13, 13]              16
#   ConvTranspose2d-62           [-1, 96, 25, 25]           6,912
#              ReLU-63           [-1, 96, 25, 25]               0
#   ConvTranspose2d-64           [-1, 96, 25, 25]          82,944
#              ReLU-65           [-1, 96, 25, 25]               0
#   ConvTranspose2d-66            [-1, 8, 25, 25]           6,912
#       BatchNorm2d-67            [-1, 8, 25, 25]              16
#   ConvTranspose2d-68           [-1, 96, 50, 50]           6,912
#              ReLU-69           [-1, 96, 50, 50]               0
#   ConvTranspose2d-70           [-1, 96, 50, 50]          82,944
#              ReLU-71           [-1, 96, 50, 50]               0
#   ConvTranspose2d-72            [-1, 8, 50, 50]           6,912
#       BatchNorm2d-73            [-1, 8, 50, 50]              16
#   ConvTranspose2d-74         [-1, 96, 100, 100]           6,912
#              ReLU-75         [-1, 96, 100, 100]               0
#   ConvTranspose2d-76         [-1, 96, 100, 100]          82,944
#              ReLU-77         [-1, 96, 100, 100]               0
#   ConvTranspose2d-78          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-79          [-1, 8, 100, 100]              16
#   ConvTranspose2d-80         [-1, 96, 200, 200]           6,912
#              ReLU-81         [-1, 96, 200, 200]               0
#   ConvTranspose2d-82         [-1, 96, 200, 200]          82,944
#              ReLU-83         [-1, 96, 200, 200]               0
#   ConvTranspose2d-84          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-85          [-1, 8, 200, 200]              16
#   ConvTranspose2d-86         [-1, 96, 400, 400]           6,912
#              ReLU-87         [-1, 96, 400, 400]               0
#   ConvTranspose2d-88         [-1, 96, 400, 400]          82,944
#              ReLU-89         [-1, 96, 400, 400]               0
#   ConvTranspose2d-90          [-1, 8, 400, 400]           6,912
#       BatchNorm2d-91          [-1, 8, 400, 400]              16
#   ConvTranspose2d-92         [-1, 96, 800, 800]           6,912
#              ReLU-93         [-1, 96, 800, 800]               0
#   ConvTranspose2d-94         [-1, 96, 800, 800]          82,944
#              ReLU-95         [-1, 96, 800, 800]               0
#   ConvTranspose2d-96          [-1, 3, 800, 800]           2,592
#              Tanh-97          [-1, 3, 800, 800]               0
# ================================================================
# Total params: 11,131,840
# Trainable params: 11,131,840
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 7.32
# Forward/backward pass size (MB): 5081.40
# Params size (MB): 42.46
# Estimated Total Size (MB): 5131.19
# ----------------------------------------------------------------

# %%
class Autoencoder_800(nn.Module):
    def __init__(self):
        super().__init__()
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.Dropout(p = 0.8),
            nn.Conv2d(96, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(8, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            Flatten(),
            nn.Linear(in_features=4704, out_features=1024, bias=True),
            nn.LeakyReLU(),
            nn.Linear(in_features=1024, out_features=64, bias=True)
        )
        self.decoder = nn.Sequential(
            nn.Linear(in_features=64, out_features=1024, bias=True),
            nn.LeakyReLU(),
            nn.Linear(in_features=1024, out_features=4704, bias=True),
            DeFlatten(-1, 96, 7, 7),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.ConvTranspose2d(8, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding = (1, 1), dilation = (1,1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

        )

    def forward(self, x):
        x = self.encoder(x)
        noise = Variable(torch.randn(x.size()) * 0.3)
        x = self.decoder(x + noise)
        return x

device = 'cpu'
model = Autoencoder_800().to(device)
criterion = nn.MSELoss()

# %%
from torchsummary import summary
from torchvision import models
from torch.autograd import Variable

summary(model, (3, 800, 800))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 96, 800, 800]           2,592
#          LeakyReLU-2         [-1, 96, 800, 800]               0
#             Conv2d-3         [-1, 96, 800, 800]          82,944
#          LeakyReLU-4         [-1, 96, 800, 800]               0
#            Dropout-5         [-1, 96, 800, 800]               0
#             Conv2d-6          [-1, 8, 400, 400]           6,912
#        BatchNorm2d-7          [-1, 8, 400, 400]              16
#             Conv2d-8         [-1, 96, 400, 400]           6,912
#          LeakyReLU-9         [-1, 96, 400, 400]               0
#            Conv2d-10         [-1, 96, 400, 400]          82,944
#         LeakyReLU-11         [-1, 96, 400, 400]               0
#           Dropout-12         [-1, 96, 400, 400]               0
#            Conv2d-13          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-14          [-1, 8, 200, 200]              16
#            Conv2d-15         [-1, 96, 200, 200]           6,912
#         LeakyReLU-16         [-1, 96, 200, 200]               0
#           Dropout-17         [-1, 96, 200, 200]               0
#            Conv2d-18         [-1, 96, 200, 200]          82,944
#         LeakyReLU-19         [-1, 96, 200, 200]               0
#            Conv2d-20          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-21          [-1, 8, 100, 100]              16
#            Conv2d-22         [-1, 96, 100, 100]           6,912
#         LeakyReLU-23         [-1, 96, 100, 100]               0
#            Conv2d-24         [-1, 96, 100, 100]          82,944
#         LeakyReLU-25         [-1, 96, 100, 100]               0
#           Dropout-26         [-1, 96, 100, 100]               0
#            Conv2d-27            [-1, 8, 50, 50]           6,912
#       BatchNorm2d-28            [-1, 8, 50, 50]              16
#            Conv2d-29           [-1, 96, 50, 50]           6,912
#         LeakyReLU-30           [-1, 96, 50, 50]               0
#            Conv2d-31           [-1, 96, 50, 50]          82,944
#         LeakyReLU-32           [-1, 96, 50, 50]               0
#           Dropout-33           [-1, 96, 50, 50]               0
#            Conv2d-34            [-1, 8, 25, 25]           6,912
#       BatchNorm2d-35            [-1, 8, 25, 25]              16
#            Conv2d-36           [-1, 96, 25, 25]           6,912
#         LeakyReLU-37           [-1, 96, 25, 25]               0
#            Conv2d-38           [-1, 96, 25, 25]          82,944
#         LeakyReLU-39           [-1, 96, 25, 25]               0
#           Dropout-40           [-1, 96, 25, 25]               0
#            Conv2d-41            [-1, 8, 13, 13]           6,912
#       BatchNorm2d-42            [-1, 8, 13, 13]              16
#            Conv2d-43           [-1, 96, 13, 13]           6,912
#         LeakyReLU-44           [-1, 96, 13, 13]               0
#            Conv2d-45           [-1, 96, 13, 13]          82,944
#         LeakyReLU-46           [-1, 96, 13, 13]               0
#           Dropout-47           [-1, 96, 13, 13]               0
#            Conv2d-48              [-1, 8, 7, 7]           6,912
#       BatchNorm2d-49              [-1, 8, 7, 7]              16
#            Conv2d-50             [-1, 96, 7, 7]           6,912
#         LeakyReLU-51             [-1, 96, 7, 7]               0
#           Flatten-52                 [-1, 4704]               0
#            Linear-53                 [-1, 1024]       4,817,920
#         LeakyReLU-54                 [-1, 1024]               0
#            Linear-55                   [-1, 64]          65,600
#            Linear-56                 [-1, 1024]          66,560
#         LeakyReLU-57                 [-1, 1024]               0
#            Linear-58                 [-1, 4704]       4,821,600
#         DeFlatten-59             [-1, 96, 7, 7]               0
#         LeakyReLU-60             [-1, 96, 7, 7]               0
#   ConvTranspose2d-61              [-1, 8, 7, 7]           6,912
#       BatchNorm2d-62              [-1, 8, 7, 7]              16
#   ConvTranspose2d-63           [-1, 96, 13, 13]           6,912
#         LeakyReLU-64           [-1, 96, 13, 13]               0
#   ConvTranspose2d-65           [-1, 96, 13, 13]          82,944
#         LeakyReLU-66           [-1, 96, 13, 13]               0
#   ConvTranspose2d-67            [-1, 8, 13, 13]           6,912
#       BatchNorm2d-68            [-1, 8, 13, 13]              16
#   ConvTranspose2d-69           [-1, 96, 25, 25]           6,912
#         LeakyReLU-70           [-1, 96, 25, 25]               0
#   ConvTranspose2d-71           [-1, 96, 25, 25]          82,944
#         LeakyReLU-72           [-1, 96, 25, 25]               0
#   ConvTranspose2d-73            [-1, 8, 25, 25]           6,912
#       BatchNorm2d-74            [-1, 8, 25, 25]              16
#   ConvTranspose2d-75           [-1, 96, 50, 50]           6,912
#         LeakyReLU-76           [-1, 96, 50, 50]               0
#   ConvTranspose2d-77           [-1, 96, 50, 50]          82,944
#         LeakyReLU-78           [-1, 96, 50, 50]               0
#   ConvTranspose2d-79            [-1, 8, 50, 50]           6,912
#       BatchNorm2d-80            [-1, 8, 50, 50]              16
#   ConvTranspose2d-81         [-1, 96, 100, 100]           6,912
#         LeakyReLU-82         [-1, 96, 100, 100]               0
#   ConvTranspose2d-83         [-1, 96, 100, 100]          82,944
#         LeakyReLU-84         [-1, 96, 100, 100]               0
#   ConvTranspose2d-85          [-1, 8, 100, 100]           6,912
#       BatchNorm2d-86          [-1, 8, 100, 100]              16
#   ConvTranspose2d-87         [-1, 96, 200, 200]           6,912
#         LeakyReLU-88         [-1, 96, 200, 200]               0
#   ConvTranspose2d-89         [-1, 96, 200, 200]          82,944
#         LeakyReLU-90         [-1, 96, 200, 200]               0
#   ConvTranspose2d-91          [-1, 8, 200, 200]           6,912
#       BatchNorm2d-92          [-1, 8, 200, 200]              16
#   ConvTranspose2d-93         [-1, 96, 400, 400]           6,912
#         LeakyReLU-94         [-1, 96, 400, 400]               0
#   ConvTranspose2d-95         [-1, 96, 400, 400]          82,944
#         LeakyReLU-96         [-1, 96, 400, 400]               0
#   ConvTranspose2d-97          [-1, 8, 400, 400]           6,912
#       BatchNorm2d-98          [-1, 8, 400, 400]              16
#   ConvTranspose2d-99         [-1, 96, 800, 800]           6,912
#        LeakyReLU-100         [-1, 96, 800, 800]               0
#  ConvTranspose2d-101         [-1, 96, 800, 800]          82,944
#        LeakyReLU-102         [-1, 96, 800, 800]               0
#  ConvTranspose2d-103          [-1, 3, 800, 800]           2,592
# ================================================================
# Total params: 11,131,840
# Trainable params: 11,131,840
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 7.32
# Forward/backward pass size (MB): 5691.72
# Params size (MB): 42.46
# Estimated Total Size (MB): 5741.51
# ----------------------------------------------------------------
