# %%
# Import some libraries
from modules.parts_top_view_AE import Autoencoder
from modules.encodings_dataset import EncodingsDataset
from modules.module_utils import Flatten
from modules.module_utils import DeFlatten
from torchvision import models

import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.datasets as datasets

import os
import pickle
import numpy as np

from PIL import Image

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = models.resnet18()
model.fc = nn.Linear(512, 64)
model = model.to(device)
criterion = nn.MSELoss()


batch_size = 32
workers = 2

train_dataset = EncodingsDataset(
    '../artifacts',
    'ae_latent_noise_gpu_model_b64_w2_e10.pt',
    'front',
    'train',
    transforms.Compose(
        [
            transforms.Normalize(
                mean = [0.485, 0.456, 0.406],
                std = [0.229, 0.224, 0.225],
            )
        ]
    )
)

val_dataset = EncodingsDataset(
    '../artifacts',
    'ae_latent_noise_gpu_model_b64_w2_e10.pt',
    'front',
    'val',
    transforms.Compose(
        [
            transforms.Normalize(
                mean = [0.485, 0.456, 0.406],
                std = [0.229, 0.224, 0.225]
            )
        ]
    )
)


train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True,
        num_workers=workers, pin_memory=True, sampler=None)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size, shuffle=True,
    num_workers=workers, pin_memory=True)

learning_rate = 1e-1

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=learning_rate,
)

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
num_epochs = 50
dataset_len = len(train_loader.dataset)
val_dataset_len = len(val_loader.dataset)
validation_losses = []
running_avg_training_losses = []

for epoch in range(num_epochs):
    torch.cuda.empty_cache()
    total = 0
    running_total_training_loss = 0

    print(f'-- running epoch {epoch + 1} --')

    for data in train_loader:
        img, expected_output = data
        img = img.to(device)
        expected_output = expected_output.to(device)
        expected_output = expected_output.view(expected_output.shape[0], expected_output.shape[2])
        # ===================forward=====================
        output = model(img) 
        loss = criterion(output, expected_output)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total += 1    

        running_total_training_loss += float(loss)    
#         if len(validation_losses) == 0:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}')
#         else:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}, validation loss (prev epoch):{validation_losses[-1]}')
    
    running_avg_training_losses.append(running_total_training_loss/total)

#     with torch.no_grad():
#         total_vloss = 0
#         for val_data in val_loader:
#             vimg, v_expected_output = val_data
#             vimg = vimg.to(device)
#             voutput = model(vimg)
#             vloss = criterion(voutput, v_expected_output)
#             total_vloss += vloss
#         validation_losses.append(total_vloss)


    print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, running avg training loss:{running_avg_training_losses[-1]:.4f}')
#     print(validation_losses)

    if (epoch + 1) % 10 == 0:
        if torch.cuda.is_available():
            torch.save(model, '../artifacts/models/cnn_front_gpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(torch.device('cpu'))
            torch.save(model, '../artifacts/models/cnn_front_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(device)   
        else:
            torch.save(model, '../artifacts/models/cnn_front_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
# Out:
# -- running epoch 1 --
# epoch [1/50], data trained:3.154%, running avg training loss:2563.2420
# -- running epoch 2 --
# epoch [2/50], data trained:3.154%, running avg training loss:2301.7611
# -- running epoch 3 --
# epoch [3/50], data trained:3.154%, running avg training loss:2066.7308
# -- running epoch 4 --
# epoch [4/50], data trained:3.154%, running avg training loss:1883.2386
# -- running epoch 5 --
# epoch [5/50], data trained:3.154%, running avg training loss:1719.9577
# -- running epoch 6 --
# epoch [6/50], data trained:3.154%, running avg training loss:1499.8524
# -- running epoch 7 --
# epoch [7/50], data trained:3.154%, running avg training loss:1360.6666
# -- running epoch 8 --
# epoch [8/50], data trained:3.154%, running avg training loss:1217.8256
# -- running epoch 9 --
# epoch [9/50], data trained:3.154%, running avg training loss:1076.1010
# -- running epoch 10 --
# epoch [10/50], data trained:3.154%, running avg training loss:957.7312
# -- running epoch 11 --
# epoch [11/50], data trained:3.154%, running avg training loss:839.0118
# -- running epoch 12 --
# epoch [12/50], data trained:3.154%, running avg training loss:717.4444
# -- running epoch 13 --
# epoch [13/50], data trained:3.154%, running avg training loss:624.6003
# -- running epoch 14 --
# epoch [14/50], data trained:3.154%, running avg training loss:553.9913
# -- running epoch 15 --
# epoch [15/50], data trained:3.154%, running avg training loss:471.4322
# -- running epoch 16 --
# epoch [16/50], data trained:3.154%, running avg training loss:413.0488
# -- running epoch 17 --
# epoch [17/50], data trained:3.154%, running avg training loss:358.3489
# -- running epoch 18 --
# epoch [18/50], data trained:3.154%, running avg training loss:316.4025
# -- running epoch 19 --
# epoch [19/50], data trained:3.154%, running avg training loss:277.0887
# -- running epoch 20 --
# epoch [20/50], data trained:3.154%, running avg training loss:263.4297
# -- running epoch 21 --
# epoch [21/50], data trained:3.154%, running avg training loss:247.3836
# -- running epoch 22 --
# epoch [22/50], data trained:3.154%, running avg training loss:228.7675
# -- running epoch 23 --
# epoch [23/50], data trained:3.154%, running avg training loss:219.1108
# -- running epoch 24 --
# epoch [24/50], data trained:3.154%, running avg training loss:205.8283
# -- running epoch 25 --
# epoch [25/50], data trained:3.154%, running avg training loss:182.2238
# -- running epoch 26 --
# epoch [26/50], data trained:3.154%, running avg training loss:170.0343
# -- running epoch 27 --
# epoch [27/50], data trained:3.154%, running avg training loss:161.8161
# -- running epoch 28 --
# epoch [28/50], data trained:3.154%, running avg training loss:148.6220
# -- running epoch 29 --
# epoch [29/50], data trained:3.154%, running avg training loss:145.6701
# -- running epoch 30 --
# epoch [30/50], data trained:3.154%, running avg training loss:140.4767
# -- running epoch 31 --
# epoch [31/50], data trained:3.154%, running avg training loss:135.2227
# -- running epoch 32 --
# epoch [32/50], data trained:3.154%, running avg training loss:139.8833
# -- running epoch 33 --
# epoch [33/50], data trained:3.154%, running avg training loss:130.3429
# -- running epoch 34 --
# epoch [34/50], data trained:3.154%, running avg training loss:116.5293
# -- running epoch 35 --
# epoch [35/50], data trained:3.154%, running avg training loss:123.8255
# -- running epoch 36 --
# epoch [36/50], data trained:3.154%, running avg training loss:127.2223
# -- running epoch 37 --
# epoch [37/50], data trained:3.154%, running avg training loss:130.3345
# -- running epoch 38 --
# epoch [38/50], data trained:3.154%, running avg training loss:129.3325
# -- running epoch 39 --
# epoch [39/50], data trained:3.154%, running avg training loss:110.0545
# -- running epoch 40 --
# epoch [40/50], data trained:3.154%, running avg training loss:104.0871
# -- running epoch 41 --
# epoch [41/50], data trained:3.154%, running avg training loss:105.1772
# -- running epoch 42 --
# epoch [42/50], data trained:3.154%, running avg training loss:100.4792
# -- running epoch 43 --

# %%
model = torch.load('../artifacts/models/cnn_latent_noise_gpu_model_b64_w2_e140.pt')
model = model.to(device)

# %%
num_epochs = 250
dataset_len = len(train_loader.dataset)
val_dataset_len = len(val_loader.dataset)
validation_losses = []
running_avg_training_losses = []

for epoch in range(140, num_epochs):
    torch.cuda.empty_cache()
    total = 0
    running_total_training_loss = 0

    print(f'-- running epoch {epoch + 1} --')

    for data in train_loader:
        img, expected_output = data
        img = img.to(device)
        expected_output = expected_output.to(device)
        expected_output = expected_output.view(expected_output.shape[0], expected_output.shape[2])
        # ===================forward=====================
        output = model(img) 
        loss = criterion(output, expected_output)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total += 1    

        running_total_training_loss += float(loss)    
#         if len(validation_losses) == 0:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}')
#         else:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}, validation loss (prev epoch):{validation_losses[-1]}')
    
    running_avg_training_losses.append(running_total_training_loss/total)

    with torch.no_grad():
        total_vloss = 0
        for val_data in val_loader:
            vimg, v_expected_output = val_data
            vimg = vimg.to(device)
            voutput = model(vimg)
            vloss = criterion(voutput, v_expected_output)
            total_vloss += vloss
        validation_losses.append(total_vloss)


    print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, running avg training loss:{running_avg_training_losses[-1]:.4f}')
    print(validation_losses)

    if (epoch + 1) % 10 == 0:
        if torch.cuda.is_available():
            torch.save(model, '../artifacts/models/cnn_latent_noise_gpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(torch.device('cpu'))
            torch.save(model, '../artifacts/models/cnn_latent_noise_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(device)   
        else:
            torch.save(model, '../artifacts/models/cnn_latent_noise_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
# Out:
# -- running epoch 141 --
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-2d1bdfd3df65> in <module>
#      41             vimg = vimg.to(device)
#      42             voutput = model(vimg)
# ---> 43             vloss = criterion(voutput, v_expected_output)
#      44             total_vloss += vloss
#      45         validation_losses.append(total_vloss)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     430
#     431     def forward(self, input, target):
# --> 432         return F.mse_loss(input, target, reduction=self.reduction)
#     433
#     434
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    2541     else:
#    2542         expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2543         ret = torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2544     return ret
#    2545
#
# RuntimeError: expected device cuda:0 but got device cpu
