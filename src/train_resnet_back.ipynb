# %%
# Import some libraries
from modules.parts_top_view_AE import Autoencoder
from modules.encodings_dataset import EncodingsDataset
from modules.module_utils import Flatten
from modules.module_utils import DeFlatten
from torchvision import models

import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.datasets as datasets

import os
import pickle
import numpy as np

from PIL import Image

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = models.resnet18()
model.fc = nn.Linear(512, 64)
model = model.to(device)
criterion = nn.MSELoss()


batch_size = 32
workers = 2

train_dataset = EncodingsDataset(
    '../artifacts',
    'ae_latent_noise_gpu_model_b64_w2_e10.pt',
    'back',
    'train',
    transforms.Compose(
        [
            transforms.Normalize(
                mean = [0.485, 0.456, 0.406],
                std = [0.229, 0.224, 0.225],
            )
        ]
    )
)

val_dataset = EncodingsDataset(
    '../artifacts',
    'ae_latent_noise_gpu_model_b64_w2_e10.pt',
    'back',
    'val',
    transforms.Compose(
        [
            transforms.Normalize(
                mean = [0.485, 0.456, 0.406],
                std = [0.229, 0.224, 0.225]
            )
        ]
    )
)


train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True,
        num_workers=workers, pin_memory=True, sampler=None)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size, shuffle=True,
    num_workers=workers, pin_memory=True)

learning_rate = 1e-1

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=learning_rate,
)

# %%
num_epochs = 50
dataset_len = len(train_loader.dataset)
val_dataset_len = len(val_loader.dataset)
validation_losses = []
running_avg_training_losses = []

for epoch in range(num_epochs):
    torch.cuda.empty_cache()
    total = 0
    running_total_training_loss = 0

    print(f'-- running epoch {epoch + 1} --')

    for data in train_loader:
        img, expected_output = data
        img = img.to(device)
        expected_output = expected_output.to(device)
        expected_output = expected_output.view(expected_output.shape[0], expected_output.shape[2])
        # ===================forward=====================
        output = model(img) 
        loss = criterion(output, expected_output)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total += 1    

        running_total_training_loss += float(loss)    
#         if len(validation_losses) == 0:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}')
#         else:
#             print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}, validation loss (prev epoch):{validation_losses[-1]}')
    
    running_avg_training_losses.append(running_total_training_loss/total)

#     with torch.no_grad():
#         total_vloss = 0
#         for val_data in val_loader:
#             vimg, v_expected_output = val_data
#             vimg = vimg.to(device)
#             voutput = model(vimg)
#             vloss = criterion(voutput, v_expected_output)
#             total_vloss += vloss
#         validation_losses.append(total_vloss)


    print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, running avg training loss:{running_avg_training_losses[-1]:.4f}')
#     print(validation_losses)

    if (epoch + 1) % 10 == 0:
        if torch.cuda.is_available():
            torch.save(model, '../artifacts/models/cnn_back_gpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(torch.device('cpu'))
            torch.save(model, '../artifacts/models/cnn_back_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
            model.to(device)   
        else:
            torch.save(model, '../artifacts/models/cnn_back_cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
# Out:
# -- running epoch 1 --
# epoch [1/50], data trained:3.154%, running avg training loss:1492.0697
# -- running epoch 2 --
# epoch [2/50], data trained:3.154%, running avg training loss:1275.2807
# -- running epoch 3 --
# epoch [3/50], data trained:3.154%, running avg training loss:1101.8809
# -- running epoch 4 --
# epoch [4/50], data trained:3.154%, running avg training loss:897.4065
# -- running epoch 5 --
# epoch [5/50], data trained:3.154%, running avg training loss:745.9282
# -- running epoch 6 --
# epoch [6/50], data trained:3.154%, running avg training loss:657.0566
# -- running epoch 7 --
# epoch [7/50], data trained:3.154%, running avg training loss:550.5681
# -- running epoch 8 --
# epoch [8/50], data trained:3.154%, running avg training loss:484.0717
# -- running epoch 9 --
# epoch [9/50], data trained:3.154%, running avg training loss:404.4595
# -- running epoch 10 --
# epoch [10/50], data trained:3.154%, running avg training loss:351.2934
# -- running epoch 11 --
# epoch [11/50], data trained:3.154%, running avg training loss:301.6137
# -- running epoch 12 --
# epoch [12/50], data trained:3.154%, running avg training loss:246.8713
# -- running epoch 13 --
# epoch [13/50], data trained:3.154%, running avg training loss:209.3628
# -- running epoch 14 --
# epoch [14/50], data trained:3.154%, running avg training loss:178.0246
# -- running epoch 15 --
# epoch [15/50], data trained:3.154%, running avg training loss:167.6428
# -- running epoch 16 --
# epoch [16/50], data trained:3.154%, running avg training loss:141.8202
# -- running epoch 17 --
# epoch [17/50], data trained:3.154%, running avg training loss:129.0381
# -- running epoch 18 --
# epoch [18/50], data trained:3.154%, running avg training loss:117.7712
# -- running epoch 19 --
# epoch [19/50], data trained:3.154%, running avg training loss:114.2406
# -- running epoch 20 --
# epoch [20/50], data trained:3.154%, running avg training loss:106.4389
# -- running epoch 21 --
# epoch [21/50], data trained:3.154%, running avg training loss:98.0487
# -- running epoch 22 --
# epoch [22/50], data trained:3.154%, running avg training loss:88.0901
# -- running epoch 23 --
# epoch [23/50], data trained:3.154%, running avg training loss:82.4943
# -- running epoch 24 --
# epoch [24/50], data trained:3.154%, running avg training loss:75.4739
# -- running epoch 25 --
# epoch [25/50], data trained:3.154%, running avg training loss:81.9675
# -- running epoch 26 --
# epoch [26/50], data trained:3.154%, running avg training loss:76.6000
# -- running epoch 27 --
# epoch [27/50], data trained:3.154%, running avg training loss:70.6776
# -- running epoch 28 --
# epoch [28/50], data trained:3.154%, running avg training loss:67.8009
# -- running epoch 29 --
# epoch [29/50], data trained:3.154%, running avg training loss:66.9850
# -- running epoch 30 --
# epoch [30/50], data trained:3.154%, running avg training loss:66.2033
# -- running epoch 31 --
# epoch [31/50], data trained:3.154%, running avg training loss:63.5969
# -- running epoch 32 --
# epoch [32/50], data trained:3.154%, running avg training loss:61.1093
# -- running epoch 33 --
# epoch [33/50], data trained:3.154%, running avg training loss:64.1710
# -- running epoch 34 --
# epoch [34/50], data trained:3.154%, running avg training loss:58.0437
# -- running epoch 35 --
# epoch [35/50], data trained:3.154%, running avg training loss:56.9040
# -- running epoch 36 --
# epoch [36/50], data trained:3.154%, running avg training loss:52.7180
# -- running epoch 37 --
# epoch [37/50], data trained:3.154%, running avg training loss:52.6900
# -- running epoch 38 --
# epoch [38/50], data trained:3.154%, running avg training loss:52.2834
# -- running epoch 39 --
# epoch [39/50], data trained:3.154%, running avg training loss:48.7022
# -- running epoch 40 --
# epoch [40/50], data trained:3.154%, running avg training loss:52.5902
# -- running epoch 41 --
# epoch [41/50], data trained:3.154%, running avg training loss:55.9197
# -- running epoch 42 --
# epoch [42/50], data trained:3.154%, running avg training loss:52.2063
# -- running epoch 43 --
# epoch [43/50], data trained:3.154%, running avg training loss:55.8882
# -- running epoch 44 --
# epoch [44/50], data trained:3.154%, running avg training loss:53.6120
# -- running epoch 45 --
# epoch [45/50], data trained:3.154%, running avg training loss:48.0581
# -- running epoch 46 --
# epoch [46/50], data trained:3.154%, running avg training loss:46.1248
# -- running epoch 47 --
